# %% [markdown]
# ### And now - Week 3 Day 3
#
# ## AutoGen Core
#
# Something a little different.
#
# This is agnostic to the underlying Agent framework
#
# You can use AutoGen AgentChat, or you can use something else; it's an Agent interaction framework.
#
# From that point of view, it's positioned similarly to LangGraph.
#
# ### The fundamental principle
#
# Autogen Core decouples an agent's logic from how messages are delivered.
# The framework provides a communication infrastructure, along with agent lifecycle, and the agents are responsible for their own work.
#
# The communication infrastructure is called a Runtime.
#
# There are 2 types: **Standalone** and **Distributed**.
#
# Today we will use a standalone runtime: the **SingleThreadedAgentRuntime**, a local embedded agent runtime implementation.
#
# Tomorrow we'll briefly look at a Distributed runtime.

# %%
from dataclasses import dataclass
from autogen_core import AgentId, MessageContext, RoutedAgent, message_handler
from autogen_core import SingleThreadedAgentRuntime
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.messages import TextMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### First we define our Message object
#
# Whatever structure we want for messages in our Agent framework.

# %%
# Let's have a simple one!

@dataclass
class Message:
    content: str

# %% [markdown]
# ### Now we define our Agent
#
# A subclass of RoutedAgent.
#
# Every Agent has an **Agent ID** which has 2 components:
# `agent.id.type` describes the kind of agent it is
# `agent.id.key` gives it its unique identifier
#
# Any method with the `@message_handler` decorated will have the opportunity to receive messages.

# %%
class SimpleAgent(RoutedAgent):
    def __init__(self) -> None:
        super().__init__("Simple")

    @message_handler
    async def on_my_message(self, message: Message, ctx: MessageContext) -> Message:
        return Message(content=f"This is {self.id.type}-{self.id.key}. You said '{message.content}' and I disagree.")

# %% [markdown]
# ### OK let's create a Standalone runtime and register our agent type

# %%
runtime = SingleThreadedAgentRuntime()
await SimpleAgent.register(runtime, "simple_agent", lambda: SimpleAgent())
# Out:
# AgentType(type='simple_agent')

# %% [markdown]
# ### Alright! Let's start a runtime and send a message

# %%
runtime.start()

# %%
agent_id = AgentId("simple_agent", "default")
response = await runtime.send_message(Message("Well hi there!"), agent_id)
print(">>>", response.content)
# Out:
# >>> This is simple_agent-default. You said 'Well hi there!' and I disagree.

# %%
await runtime.stop()
await runtime.close()

# %% [markdown]
# ### OK Now let's do something more interesting
#
# We'll use an AgentChat Assistant!

# %%
class MyLLMAgent(RoutedAgent):
    def __init__(self) -> None:
        super().__init__("LLMAgent")
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
        self._delegate = AssistantAgent("LLMAgent", model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        print(f"{self.id.type} received message: {message.content}")
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        reply = response.chat_message.content
        print(f"{self.id.type} responded: {reply}")
        return Message(content=reply)

# %%
from autogen_core import SingleThreadedAgentRuntime

runtime = SingleThreadedAgentRuntime()
await SimpleAgent.register(runtime, "simple_agent", lambda: SimpleAgent())
await MyLLMAgent.register(runtime, "LLMAgent", lambda: MyLLMAgent())
# Out:
# AgentType(type='LLMAgent')

# %%
runtime.start()  # Start processing messages in the background.
response = await runtime.send_message(Message("Hi there!"), AgentId("LLMAgent", "default"))
print(">>>", response.content)
response =  await runtime.send_message(Message(response.content), AgentId("simple_agent", "default"))
print(">>>", response.content)
response = await runtime.send_message(Message(response.content), AgentId("LLMAgent", "default"))
# Out:
# LLMAgent received message: Hi there!
# LLMAgent responded: Hello! How can I assist you today?
# >>> Hello! How can I assist you today?
# >>> This is simple_agent-default. You said 'Hello! How can I assist you today?' and I disagree.
# LLMAgent received message: This is simple_agent-default. You said 'Hello! How can I assist you today?' and I disagree.
# LLMAgent responded: I appreciate your feedback! How would you prefer me to respond?

# %%
await runtime.stop()
await runtime.close()

# %% [markdown]
# ### OK now let's show this at work - let's have 3 agents interact!

# %%
from autogen_ext.models.ollama import OllamaChatCompletionClient


class Player1Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Player2Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OpenAIChatCompletionClient(model="claude-3-5-sonnet-20240620", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)

# %%
JUDGE = "You are judging a game of rock, paper, scissors. The players have made these choices:\n"

class RockPaperScissorsAgent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        instruction = "You are playing rock, paper, scissors. Respond only with the one word, one of the following: rock, paper, or scissors."
        message = Message(content=instruction)
        inner_1 = AgentId("player1", "default")
        inner_2 = AgentId("player2", "default")
        response1 = await self.send_message(message, inner_1)
        response2 = await self.send_message(message, inner_2)
        result = f"Player 1: {response1.content}\nPlayer 2: {response2.content}\n"
        judgement = f"{JUDGE}{result}Who wins?"
        message = TextMessage(content=judgement, source="user")
        response = await self._delegate.on_messages([message], ctx.cancellation_token)
        return Message(content=result + response.chat_message.content)

# %%
runtime = SingleThreadedAgentRuntime()
await Player1Agent.register(runtime, "player1", lambda: Player1Agent("player1"))
await Player2Agent.register(runtime, "player2", lambda: Player2Agent("player2"))
await RockPaperScissorsAgent.register(runtime, "rock_paper_scissors", lambda: RockPaperScissorsAgent("rock_paper_scissors"))
runtime.start()
# Out:
# Error constructing agent player2/default
# Traceback (most recent call last):
#   File "/Users/Srinidhi_1/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py", line 963, in _invoke_agent_factory
#     agent = cast(T, await agent)
#                     ^^^^^^^^^^^
#   File "/Users/Srinidhi_1/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py", line 900, in factory_wrapper
#     maybe_agent_instance = agent_factory()
#                            ^^^^^^^^^^^^^^^
#   File "/var/folders/v7/1zw7w7zj3qgfrkv27k0w1ppr0000gn/T/ipykernel_14478/386285989.py", line 3, in <lambda>
#     await Player2Agent.register(runtime, "player2", lambda: Player2Agent("player2"))
#                                                             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/v7/1zw7w7zj3qgfrkv27k0w1ppr0000gn/T/ipykernel_14478/3274324643.py", line 19, in __init__
#     model_client = OpenAIChatCompletionClient(model="claude-3-5-sonnet-20240620", temperature=1.0)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Srinidhi_1/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py", line 1487, in __init__
#     super().__init__(
#   File "/Users/Srinidhi_1/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py", line 448, in __init__
#     self._model_info = _model_info.get_info(create_args["model"])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Srinidhi_1/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_model_info.py", line 521, in get_info
#     raise ValueError("model_info is required when model name is not a valid OpenAI model")
# ValueError: model_info is required when model name is not a valid OpenAI model

# %%
agent_id = AgentId("rock_paper_scissors", "default")
message = Message(content="go")
response = await runtime.send_message(message, agent_id)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 agent_id = AgentId("rock_paper_scissors", "default")
#       2 message = Message(content="go")
# ----> 3 response = await runtime.send_message(message, agent_id)
#       4 print(response.content)
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:385, in SingleThreadedAgentRuntime.send_message(self, message, recipient, sender, cancellation_token, message_id)
#     371 await self._message_queue.put(
#     372     SendMessageEnvelope(
#     373         message=message,
#    (...)    380     )
#     381 )
#     383 cancellation_token.link_future(future)
# --> 385 return await future
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:508, in SingleThreadedAgentRuntime._process_send(self, message_envelope)
#     496     with self._tracer_helper.trace_block(
#     497         "process",
#     498         recipient_agent.id,
#    (...)    505         ),
#     506     ):
#     507         with MessageHandlerContext.populate_context(recipient_agent.id):
# --> 508             response = await recipient_agent.on_message(
#     509                 message_envelope.message,
#     510                 ctx=message_context,
#     511             )
#     512 except CancelledError as e:
#     513     if not message_envelope.future.cancelled():
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:119, in BaseAgent.on_message(self, message, ctx)
#     117 @final
#     118 async def on_message(self, message: Any, ctx: MessageContext) -> Any:
# --> 119     return await self.on_message_impl(message, ctx)
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:485, in RoutedAgent.on_message_impl(self, message, ctx)
#     483     for h in handlers:
#     484         if h.router(message, ctx):
# --> 485             return await h(self, message, ctx)
#     486 return await self.on_unhandled_message(message, ctx)
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:149, in message_handler.<locals>.decorator.<locals>.wrapper(self, message, ctx)
#     146     else:
#     147         logger.warning(f"Message type {type(message)} not in target types {target_types}")
# --> 149 return_value = await func(self, message, ctx)
#     151 if AnyType not in return_types and type(return_value) not in return_types:
#     152     if strict:
#
# Cell In[22], line 16, in RockPaperScissorsAgent.handle_my_message_type(self, message, ctx)
#      14 inner_2 = AgentId("player2", "default")
#      15 response1 = await self.send_message(message, inner_1)
# ---> 16 response2 = await self.send_message(message, inner_2)
#      17 result = f"Player 1: {response1.content}\nPlayer 2: {response2.content}\n"
#      18 judgement = f"{JUDGE}{result}Who wins?"
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:136, in BaseAgent.send_message(self, message, recipient, cancellation_token, message_id)
#     133 if cancellation_token is None:
#     134     cancellation_token = CancellationToken()
# --> 136 return await self._runtime.send_message(
#     137     message,
#     138     sender=self.id,
#     139     recipient=recipient,
#     140     cancellation_token=cancellation_token,
#     141     message_id=message_id,
#     142 )
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:385, in SingleThreadedAgentRuntime.send_message(self, message, recipient, sender, cancellation_token, message_id)
#     371 await self._message_queue.put(
#     372     SendMessageEnvelope(
#     373         message=message,
#    (...)    380     )
#     381 )
#     383 cancellation_token.link_future(future)
# --> 385 return await future
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:487, in SingleThreadedAgentRuntime._process_send(self, message_envelope)
#     475 logger.info(
#     476     f"Calling message handler for {recipient} with message type {type(message_envelope.message).__name__} sent by {sender_id}"
#     477 )
#     478 event_logger.info(
#     479     MessageEvent(
#     480         payload=self._try_serialize(message_envelope.message),
#    (...)    485     )
#     486 )
# --> 487 recipient_agent = await self._get_agent(recipient)
#     489 message_context = MessageContext(
#     490     sender=message_envelope.sender,
#     491     topic_id=None,
#    (...)    494     message_id=message_envelope.message_id,
#     495 )
#     496 with self._tracer_helper.trace_block(
#     497     "process",
#     498     recipient_agent.id,
#    (...)    505     ),
#     506 ):
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:984, in SingleThreadedAgentRuntime._get_agent(self, agent_id)
#     981     raise LookupError(f"Agent with name {agent_id.type} not found.")
#     983 agent_factory = self._agent_factories[agent_id.type]
# --> 984 agent = await self._invoke_agent_factory(agent_factory, agent_id)
#     985 self._instantiated_agents[agent_id] = agent
#     986 return agent
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:963, in SingleThreadedAgentRuntime._invoke_agent_factory(self, agent_factory, agent_id)
#     960         raise ValueError("Agent factory must take 0 or 2 arguments.")
#     962     if inspect.isawaitable(agent):
# --> 963         agent = cast(T, await agent)
#     964     return agent
#     966 except BaseException as e:
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:900, in SingleThreadedAgentRuntime.register_factory.<locals>.factory_wrapper()
#     899 async def factory_wrapper() -> T:
# --> 900     maybe_agent_instance = agent_factory()
#     901     if inspect.isawaitable(maybe_agent_instance):
#     902         agent_instance = await maybe_agent_instance
#
# Cell In[23], line 3, in <lambda>()
#       1 runtime = SingleThreadedAgentRuntime()
#       2 await Player1Agent.register(runtime, "player1", lambda: Player1Agent("player1"))
# ----> 3 await Player2Agent.register(runtime, "player2", lambda: Player2Agent("player2"))
#       4 await RockPaperScissorsAgent.register(runtime, "rock_paper_scissors", lambda: RockPaperScissorsAgent("rock_paper_scissors"))
#       5 runtime.start()
#
# Cell In[21], line 19, in Player2Agent.__init__(self, name)
#      17 def __init__(self, name: str) -> None:
#      18     super().__init__(name)
# ---> 19     model_client = OpenAIChatCompletionClient(model="claude-3-5-sonnet-20240620", temperature=1.0)
#      20     self._delegate = AssistantAgent(name, model_client=model_client)
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py:1487, in OpenAIChatCompletionClient.__init__(self, **kwargs)
#    1484 client = _openai_client_from_config(copied_args)
#    1485 create_args = _create_args_from_config(copied_args)
# -> 1487 super().__init__(
#    1488     client=client,
#    1489     create_args=create_args,
#    1490     model_capabilities=model_capabilities,
#    1491     model_info=model_info,
#    1492     add_name_prefixes=add_name_prefixes,
#    1493     include_name_in_message=include_name_in_message,
#    1494 )
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py:448, in BaseOpenAIChatCompletionClient.__init__(self, client, create_args, model_capabilities, model_info, add_name_prefixes, include_name_in_message)
#     446 if model_capabilities is None and model_info is None:
#     447     try:
# --> 448         self._model_info = _model_info.get_info(create_args["model"])
#     449     except KeyError as err:
#     450         raise ValueError("model_info is required when model name is not a valid OpenAI model") from err
#
# File ~/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_model_info.py:521, in get_info(model)
#     510 model_info: ModelInfo = _MODEL_INFO.get(
#     511     resolved_model,
#     512     {
#    (...)    518     },
#     519 )
#     520 if model_info.get("family") == "FAILED":
# --> 521     raise ValueError("model_info is required when model name is not a valid OpenAI model")
#     522 if model_info.get("family") == ModelFamily.UNKNOWN:
#     523     trace_logger.warning(f"Model info not found for model: {model}")
#
# ValueError: model_info is required when model name is not a valid OpenAI model

# %%
await runtime.stop()
await runtime.close()
